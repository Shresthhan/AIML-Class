# %%
import pandas as pd

# %%
file_path = '/content/raw_dataset.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.sample(10)
# Out:
#       ID       Name   Age   Gender   Salary Department Joining_Date  \
# 38    39      David  25.0      NaN  50000.0         HR   2021-03-20
# 32    33      Alice  30.0        M  80000.0        it    2019-07-01
# 209  169      Alice  35.0  Unknown  80000.0        it    2022-11-11
# 41    42        NaN  45.0        M  40000.0    finance   2022-11-11
# 167  168    Charlie  30.0   Female  80000.0         HR   2020-01-15
# 134  135        Eva  20.0      NaN  80000.0        NaN   2019-07-01
# 156  157        Eva   NaN        F  40000.0    Finance          NaN
# 146  147    Alice    50.0        F      NaN         IT   2021-03-20
# 31    32      Alice  50.0      NaN  60000.0         IT   2022-11-11
# 45    46      David  50.0  Unknown  40000.0    Finance   2021-03-20
#
#      Performance_Score            Remarks
# 38                 1.0          Excellent
# 32                 3.0                NaN
# 209                3.0            Average
# 41               100.0  Needs Improvement
# 167                2.0            Average
# 134                5.0            Average
# 156                2.0                NaN
# 146              100.0          Excellent
# 31               100.0               Good
# 45                 NaN                NaN

# %% [markdown]
# # 1. Standarize the data

# %%
df["Gender"] = df["Gender"].str.strip().str.capitalize().replace({"Male":"M", "Female": "F"})

# %%
df["Name"] = df["Name"].str.strip().str.capitalize()

# %%
df["Department"] = df["Department"].str.strip().str.capitalize().replace({"It":"IT", "Hr":"HR"})

# %% [markdown]
# # 2. Handling Missing Data

# %% [markdown]
# NOTE: If in any column, the missing data covers over 50% than ideally the column is discarded.

# %%
df.isnull().sum()
# Out:
# ID                    0
# Name                 25
# Age                  13
# Gender               36
# Salary               39
# Department           34
# Joining_Date         47
# Performance_Score    30
# Remarks              33
# dtype: int64

# %%
thres = len(df) * 0.5

# %%
df = df.dropna(axis = 1, thresh = thres)

# %%
for col in df.columns:
  if df[col].dtype in ["float64", "int64"]:
    df[col] = df[col].fillna(df[col].median())
  else:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# Convert Joining_Date to date and time
df["Joining_Date"] = pd.to_datetime(df["Joining_Date"])

# %%
df.sample(10)
# Out:
#       ID   Name   Age   Gender   Salary Department Joining_Date  \
# 38    39  David  25.0        F  50000.0         HR   2021-03-20
# 7      8  Alice  35.0  Unknown  40000.0  Marketing   2020-01-15
# 165  166  Alice  50.0  Unknown  60000.0    Finance   2019-07-01
# 107  108    Bob  40.0        F  60000.0         HR   2022-11-11
# 195  196  Alice  40.0        F  60000.0         HR   2022-11-11
# 62    63    Bob  50.0        M  30000.0         HR   2020-01-15
# 150  151  David  20.0        M  50000.0         IT   2019-07-01
# 170  171  Alice  40.0        F  50000.0         IT   2020-01-15
# 78    79  David  35.0  Unknown  30000.0    Finance   2019-07-01
# 183  184    Eva  30.0        F  40000.0         IT   2021-03-20
#
#      Performance_Score            Remarks
# 38                 1.0          Excellent
# 7                100.0          Excellent
# 165                2.0            Average
# 107              100.0            Average
# 195                1.0               Good
# 62                 4.0            Average
# 150                5.0          Excellent
# 170                3.0               Good
# 78                 2.0  Needs Improvement
# 183                1.0            Average

# %%
df.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Gender               0
# Salary               0
# Department           0
# Joining_Date         0
# Performance_Score    0
# Remarks              0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                         float64
# Gender                       object
# Salary                      float64
# Department                   object
# Joining_Date         datetime64[ns]
# Performance_Score           float64
# Remarks                      object
# dtype: object

# %% [markdown]
# # 3. Ensuring Correct Datatypes

# %%
df["Age"] = df["Age"].astype("int64")
df["Salary"] = df["Salary"].astype("int64")
df["Performance_Score"] = df["Performance_Score"].astype("int64")

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Gender                       object
# Salary                        int64
# Department                   object
# Joining_Date         datetime64[ns]
# Performance_Score             int64
# Remarks                      object
# dtype: object

# %% [markdown]
# # 4. Outliers Removal using IQR

# %%
def remove_outliers_IQR(data, column):
  Q1 = data[column].quantile(0.25)
  Q3 = data[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
df = ( df
      .pipe(remove_outliers_IQR, column = "Age")
      .pipe(remove_outliers_IQR, column = "Salary")
      .pipe(remove_outliers_IQR, column = "Performance_Score")
      )

# %%
df = df.drop_duplicates()

# %%
df.sample(10)
# Out:
#       ID     Name  Age   Gender  Salary Department Joining_Date  \
# 12    13  Charlie   50  Unknown   60000    Finance   2022-11-11
# 133  134  Charlie   35        F   50000         HR   2020-01-15
# 50    51      Eva   40        M   80000  Marketing   2022-11-11
# 177  178    Alice   50        F   50000    Finance   2021-03-20
# 81    82      Bob   50        F   80000    Finance   2020-01-15
# 91    92      Bob   45        M   70000    Finance   2022-11-11
# 52    53    Alice   25        M   40000         IT   2020-01-15
# 19    20    David   20        M   50000         IT   2022-11-11
# 190  191    David   25        M   40000         IT   2020-01-15
# 157  158    Alice   35        M   50000         IT   2020-01-15
#
#      Performance_Score            Remarks
# 12                   1          Excellent
# 133                  5            Average
# 50                   3            Average
# 177                  4            Average
# 81                   3            Average
# 91                   4               Good
# 52                   1  Needs Improvement
# 19                   1               Good
# 190                  4            Average
# 157                  1          Excellent
